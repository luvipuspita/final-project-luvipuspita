# %% [markdown]
# <a href="https://colab.research.google.com/github/LUVIPUSPITA/LUVIPUSPITA/blob/main/W2D1PM_VECTOR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # VECTOR

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# penjumlahan 2 array
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

a + b
# Out:
# array([5, 7, 9])

# %%
# penjumlaha 2 list
k = [1,2,3]
l = [4,5,6]

k + l
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a[1:]
# Out:
# array([2, 3])

# %% [markdown]
# ## Vector Norm

# %%
import matplotlib.pyplot as plt

def plot_vector2d(vector2d, origin=[0, 0], **options):
    return plt.arrow(origin[0], origin[1], vector2d[0], vector2d[1],
              head_width=0.2, head_length=0.3, length_includes_head=True,
              **options)

# %%
arr = np.array([3,4])

plot_vector2d(arr)
plt.axis([0,5,0,5]) # rentang axis sumbu x dan y
plt.axvline(0)
plt.axhline(0)
plt.grid()
plt.show()

# %%
# vector norm
np.linalg.norm(arr)
# Out:
# 5.0

# %%
# manhattan distance
np.linalg.norm(arr, 1)
# Out:
# 7.0

# %%
a
# Out:
# array([1, 2, 3])

# %%
np.linalg.norm(a)
# Out:
# 3.7416573867739413

# %% [markdown]
# # Operasi Aritmatika

# %% [markdown]
# ## penjumlahan

# %%
print(a, b)
# Out:
# [1 2 3] [4 5 6]

# %%
# penjumlahan vektor dengan skalar
10 + a
# Out:
# array([11, 12, 13])

# %%
# penjumlahan vektor dengan vektor
a + b
# Out:
# array([5, 7, 9])

# %%
c = np.array([5, 7, 5, 9, 0])
a + c # akan muncul pesan error karena perbedaan shape/elemen
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-53756c944ddc> in <module>()
#       1 c = np.array([5, 7, 5, 9, 0])
# ----> 2 a + c
#
# ValueError: operands could not be broadcast together with shapes (3,) (5,)

# %%
arr_1 =  np.array([1,2])
arr_2 = np.array([3,4])

# %%
plot_vector2d(arr_1, color='r')
plot_vector2d(arr_2, origin=[1,2], color='g')
plot_vector2d(np.array([4,6]))
plt.axis([0,10,0,10]) # rentang axis sumbu x dan y
plt.axvline(0)
plt.axhline(0)
plt.grid()
plt.show()

# %%
arr_1 + arr_2
# Out:
# array([4, 6])

# %% [markdown]
# ## pengurangan

# %%
# pengurangan vektor terhapad skalar
10 - a
# Out:
# array([9, 8, 7])

# %%
# pengurangan vektor terhadap vektor
a - b
# Out:
# array([-3, -3, -3])

# %% [markdown]
# # pembagian

# %%
# pembagian vektor dengan skalar
10 / a
# Out:
# array([10.        ,  5.        ,  3.33333333])

# %%
a / 10
# Out:
# array([0.1, 0.2, 0.3])

# %%
# pembagian vektor terhadap vektor
a / b
# Out:
# array([0.25, 0.4 , 0.5 ])

# %% [markdown]
# # perkalian
# - terhadap skalar
# - dengan vector (element-wise multiplication)
# - dot product

# %%
print(a, b)
# Out:
# [1 2 3] [4 5 6]

# %%
# terhadap skalar
a * 10
# Out:
# array([10, 20, 30])

# %%
arr_3 = np.array([2, 4])
arr_4 = arr_3 * 0.5

plot_vector2d(arr_3, color='r')
plot_vector2d(arr_4, color='g')

plt.axis([0,10,0,10]) # rentang axis sumbu x dan y
plt.axvline(0)
plt.axhline(0)
plt.grid()
plt.show()

# %%
arr_4 = arr_3 * 2

# %%
# perkalian vektor terhadap vektor
a * b
# Out:
# array([ 4, 10, 18])

# %%
# dot-product
np.dot(a, b)
# Out:
# 32

# %%
a.dot(b)
# Out:
# 32

# %%
a @ b
# Out:
# 32

# %% [markdown]
# ## cosine similarity

# %%
plot_vector2d(arr_1, color='r')
plot_vector2d(arr_2, color='g')

plt.axis([0,10,0,10]) # rentang axis sumbu x dan y
plt.axvline(0)
plt.axhline(0)
plt.grid()
plt.show()

# %%
print(arr_1, arr_2)
# Out:
# [1 2] [3 4]

# %%
cos_theta = arr_1 @ arr_2 / (np.linalg.norm(arr_1) * np.linalg.norm(arr_2))
cos_theta
# Out:
# 0.9838699100999074

# %%
# sudut 90 derajat
plot_vector2d(np.array([3,0]), color='r')
plot_vector2d(np.array([0,5]), color='g')

plt.axis([0,5,0,5]) # rentang axis sumbu x dan y
plt.axvline(0)
plt.axhline(0)
plt.grid()
plt.show()

# %%
arr_3 = np.array([3,0])
arr_4 = np.array([0,5])

cos_theta = arr_3 @ arr_4 / (np.linalg.norm(arr_3) * np.linalg.norm(arr_4))
cos_theta
# Out:
# 0.0

# %%
# convert cos_theta to radian
rad = np.arccos(cos_theta)
rad
# Out:
# 1.5707963267948966

# %%
# convert radian to degrees
degree = np.degrees(rad)
degree
# Out:
# 90.0

# %%
# sudut 0 derajat
plot_vector2d(np.array([5,0]), color='r')
plot_vector2d(np.array([2,0]), color='g')

plt.axis([0,5,0,5]) # rentang axis sumbu x dan y
plt.axvline(0)
plt.axhline(0)
plt.grid()
plt.show()

# %%
arr_5 = np.array([5,0])
arr_6 = np.array([2,0])

cos_theta = arr_5 @ arr_6 / (np.linalg.norm(arr_5) * np.linalg.norm(arr_6))
cos_theta
# Out:
# 1.0

# %% [markdown]
# **contoh implementasi cosine similarity**

# %% [markdown]
# - kalimat 1 = saya pergi ke rumah kakek saya
# - kalimat 2 = saya pergi ke rumah nenek saya

# %%
kalimat_1 = np.array([2, 1, 1, 1, 1, 0])
kalimat_2 = np.array([2, 1, 1, 1, 0, 1])

cos_theta =kalimat_1 @ kalimat_2 / (np.linalg.norm(kalimat_1) * np.linalg.norm(kalimat_2))
cos_theta
# Out:
# 0.8749999999999998

# %% [markdown]
# - kalimat_1 = saya pulang dari banjarmasin
# - kalimat_2 = pagi tadi saya ujian livecode

# %%
kal_1 = np.array([1, 1, 1, 1, 0, 0, 0, 0])
kal_2 = np.array([1, 0, 0, 0, 1, 1, 1, 1])

cos_theta = kal_1 @ kal_2 / (np.linalg.norm(kal_1) * np.linalg.norm(kal_2))
cos_theta
# Out:
# 0.22360679774997896

# %% [markdown]
# - kal_1 = kucing mengejar tikus
# - kal_2 = tikus mengejar kucing

# %%
kal1 = np.array([1, 1, 1])
kal2 = np.array([1, 1, 1])

cos_theta = kal1 @ kal2 / (np.linalg.norm(kal1) * np.linalg.norm(kal2))
cos_theta
# Out:
# 1.0000000000000002
